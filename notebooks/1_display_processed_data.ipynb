# %%
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np
import ast

# %% [markdown]
# ## Image and ROIS

# %%
#Print image and roi
imgs_path = sorted(glob.glob("../data/processed/images/*"))
rois_path = sorted(glob.glob("../data/processed/rois/*"))
id_img = 0
print(imgs_path[id_img],rois_path[id_img])
plt.figure()
plt.subplot(1,2,1)
cxr = plt.imread(imgs_path[id_img])
plt.imshow(cxr,cmap="gray")
plt.title("X-Ray")
plt.subplot(1,2,2)
roi = plt.imread(rois_path[id_img])
plt.title("ROI")
plt.imshow(roi,cmap="gray")
plt.show()
# Out:
# ../data/processed/images/100014625199913409730274754282179594842_0jycky.png ../data/processed/rois/100014625199913409730274754282179594842_0jycky.png

# %% [markdown]
# ## Labels

# %%
labels = pd.read_csv("../data/processed/processed_labels.csv")
labels["Onehot"] = labels["Onehot"].apply(lambda x: ast.literal_eval(x))

# %%
lst_labels = []
for l in labels["Onehot"]:
    lst_labels.append(l)
np.sum(lst_labels,axis=0)
# Out:
# array([9659, 4995, 2146,  383, 6764])

# %%
sum(np.sum(lst_labels,axis=1) != 0)
# Out:
# 20702

# %%
len(lst_labels)
# Out:
# 108071

# %%
sum(labels[labels["ImageID"]=="20536686640136348236148679891455886468_k6ga29.png"]["Onehot"].sum()) == 0
# Out:
# True
